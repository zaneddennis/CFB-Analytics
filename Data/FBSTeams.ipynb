# %%
import pandas as pd

df = pd.read_csv("allteams.tsv", sep="\t")
df = df[df.division == "FBS"]
df
# Out:
#     abbreviation             school            mascot division
# 3            AFA          Air Force           Falcons      FBS
# 4            AKR              Akron              Zips      FBS
# 5            ALA            Alabama      Crimson Tide      FBS
# 23           APP  Appalachian State      Mountaineers      FBS
# 25          ARIZ            Arizona          Wildcats      FBS
# 27           ASU      Arizona State        Sun Devils      FBS
# 28           ARK           Arkansas        Razorbacks      FBS
# 31          ARST     Arkansas State        Red Wolves      FBS
# 33          ARMY               Army     Black Knights      FBS
# 36           AUB             Auburn            Tigers      FBS
# 50          BALL         Ball State         Cardinals      FBS
# 52           BAY             Baylor             Bears      FBS
# 72           BSU        Boise State           Broncos      FBS
# 73            BC     Boston College            Eagles      FBS
# ...
