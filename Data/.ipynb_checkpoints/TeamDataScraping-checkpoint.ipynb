# %%
import pandas as pd

df = pd.read_csv("teams_aPPD.tsv", sep="\t")
df
# Out:
#                   team      OPRE      DPRE  off_aPPD  def_aPPD  net_aPPD  AP
# 0            Air Force -0.037386 -0.034339 -0.182085  0.313110 -0.495196  NR
# 1                Akron -0.805996 -0.377049 -0.790290 -0.238068 -0.552222  NR
# 2              Alabama  1.768521 -1.122933  1.703191 -1.504534  3.207725  NR
# 3    Appalachian State  0.655309 -0.888214  0.057539 -0.746065  0.803604  NR
# 4              Arizona -0.242635  0.172190 -0.401344  0.255255 -0.656598  NR
# 5        Arizona State  0.609223  0.046989  0.614312  0.195918  0.418394  NR
# 6             Arkansas -0.521397  0.022634 -0.043401 -0.294367  0.250966  NR
# 7       Arkansas State -0.360100  0.235630 -0.348716  0.211131 -0.559847  NR
# 8                 Army  1.101578 -0.097059  1.024943 -0.104538  1.129481  NR
# 9               Auburn -0.428165 -0.718319  0.066904 -1.140377  1.207282  NR
# 10                 BYU -0.016709  0.437945  0.029888  0.423922 -0.394033  NR
# ...

# %%
df.to_csv("fbsTeams.tsv", sep="\t", index=False)
