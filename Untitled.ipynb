# %%
import pandas as pd

df = pd.read_csv("Data/teams_aPPD.tsv", sep="\t", index_col="team")
df = df[["aOPPD", "aDPPD", "net_aPPD"]].copy().sort_values(by="net_aPPD", ascending=False).round(2)
df
# Out:
#                    aOPPD  aDPPD  net_aPPD
# team
# Alabama             1.65  -1.44      3.09
# Georgia             1.52  -1.32      2.84
# Clemson             0.84  -1.35      2.19
# Michigan            0.92  -1.27      2.18
# Mississippi State   0.99  -1.19      2.18
# Florida             0.72  -1.40      2.12
# Kentucky            0.42  -1.59      2.01
# LSU                 1.05  -0.92      1.97
# Oklahoma            1.94   0.02      1.92
# Ohio State          1.36  -0.49      1.85
# Iowa                0.85  -0.99      1.84
# Penn State          0.89  -0.80      1.69
# Texas A&M           0.93  -0.72      1.65
# West Virginia       0.96  -0.59      1.55
# Army                1.23  -0.32      1.55
# South Carolina      0.69  -0.76      1.45
# Washington          0.79  -0.56      1.35
# Notre Dame          0.49  -0.85      1.34
# NC State            0.84  -0.48      1.32
# Iowa State          0.46  -0.80      1.27
# Missouri            0.68  -0.57      1.25
# ...

# %%
#outfile = open("aPPD_asTable.txt", "w")

#for index, row in df.iterrows():
#    outfile.write(index + " | " + str(row["aOPPD"]) + " | " + str(row["aDPPD"]) + " | " + str(row["net_aPPD"]) + "\n")
df.to_csv("aPPD_asTable.txt", sep="|")
